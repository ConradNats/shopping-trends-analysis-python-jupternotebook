# %%
import pandas as pd

# %%
#Define the dataset as a dictionary
data = {
    "Students": ["Aisha", "Brian", "Cathy", "Derek", "Esther", "Felix", "Gloria", "James", "Annet", "Daniel", "Brenda", "Oscar"],
    "Programme": ["BSDS", "BSCS", "BSCS", "BSIT", "BSDS", "BSCS", "BSIT", "BSDS", "BSDS", "BSCS", "BSIT", "BSDS",],
    "Sex":["F", "M", "F", "M", "F", "M", "F", "M", "F", "M", "F", "M"],
    "Study Hours":[18, 8, 22, 6, 20, 12, 14, 10, 24, 7, 9, 16],
    "Attendance":[92, 60, 95, 55, 90, 70, 80, 65, 98, 58, 62, 85],
    "Score":[78, 45, 88, 39, 83, 61, 66, 52, 91, 44, 48, 72],
    "Result":["Pass", "Fail", "Pass", "Fail", "Pass", "Pass", "Pass", "Pass", "Pass", "Fail", "Fail", "Pass"],
    "Scholarship":["Yes", "No", "Yes", "No", "Yes", "No", "No", "No", "Yes", "No", "No", "Yes"],
}

# %%
results_df = pd.DataFrame(data)
results_df
# Out:
#    Students Programme Sex  Study Hours  Attendance  Score Result Scholarship
# 0     Aisha      BSDS   F           18          92     78   Pass         Yes
# 1     Brian      BSCS   M            8          60     45   Fail          No
# 2     Cathy      BSCS   F           22          95     88   Pass         Yes
# 3     Derek      BSIT   M            6          55     39   Fail          No
# 4    Esther      BSDS   F           20          90     83   Pass         Yes
# 5     Felix      BSCS   M           12          70     61   Pass          No
# 6    Gloria      BSIT   F           14          80     66   Pass          No
# 7     James      BSDS   M           10          65     52   Pass          No
# 8     Annet      BSDS   F           24          98     91   Pass         Yes
# 9    Daniel      BSCS   M            7          58     44   Fail          No
# 10   Brenda      BSIT   F            9          62     48   Fail          No
# ...

# %% [markdown]
# The dataset has 12 rows and 8 columns

# %%
results_df.shape
print("Rows:", results_df.shape[0])
print("Columns:", results_df.shape[1])
# Out:
# Rows: 12
# Columns: 8

# %%
mean_Study_hours = results_df['Study Hours'].mean()
median_Study_hours = results_df['Study Hours'].median()
print(f"The Study Hours variable has a mean of {mean_Study_hours} and median of {median_Study_hours}")

mean_Study_hours = results_df['Attendance'].mean()
median_Study_hours = results_df['Attendance'].median()
print(f"The Attendance variable has a mean of {mean_Study_hours} and median of {median_Study_hours}")

mean_Score = results_df['Score'].mean()
median_Score = results_df['Score'].median()
print(f"The Score variable has a mean of {mean_Score} and median of {median_Score}")
# Out:
# The Study Hours variable has a mean of 13.833333333333334 and median of 13.0
# The Attendance variable has a mean of 75.83333333333333 and median of 75.0
# The Score variable has a mean of 63.916666666666664 and median of 63.5
